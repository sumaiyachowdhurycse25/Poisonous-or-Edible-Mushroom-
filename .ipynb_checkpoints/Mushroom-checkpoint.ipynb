# %%
# loading the important libraries 

import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# read the dataset 
pd.set_option("display.max_columns", None)

df = pd.read_csv('mushrooms.csv')
print(df.shape)
df.head()
# Out:
# (8124, 23)
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0            c         n          k           e          e
# 1            c         b          k           e          c
# 2            c         b          n           e          c
# 3            c         n          n           e          e
# 4            w         b          k           t          e
#
#   stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                        s                        s                      w
# 1                        s                        s                      w
# 2                        s                        s                      w
# 3                        s                        s                      w
# 4                        s                        s                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat
# 0                 k          s       u
# 1                 n          n       g
# 2                 n          n       m
# 3                 k          s       u
# 4                 n          a       g

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
for cols in df.columns:
    unique_vals = df[cols].unique()
    if len(unique_vals) <= 10:
        print("Feature ", cols, " has ", len(unique_vals), " unique values ----> ", unique_vals)
    else:
        print("Feature ", cols, " has ", len(unique_vals), " unique values")
# Out:
# Feature  class  has  2  unique values ---->  ['p' 'e']
# Feature  cap-shape  has  6  unique values ---->  ['x' 'b' 's' 'f' 'k' 'c']
# Feature  cap-surface  has  4  unique values ---->  ['s' 'y' 'f' 'g']
# Feature  cap-color  has  10  unique values ---->  ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# Feature  bruises  has  2  unique values ---->  ['t' 'f']
# Feature  odor  has  9  unique values ---->  ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# Feature  gill-attachment  has  2  unique values ---->  ['f' 'a']
# Feature  gill-spacing  has  2  unique values ---->  ['c' 'w']
# Feature  gill-size  has  2  unique values ---->  ['n' 'b']
# Feature  gill-color  has  12  unique values
# Feature  stalk-shape  has  2  unique values ---->  ['e' 't']
# Feature  stalk-root  has  5  unique values ---->  ['e' 'c' 'b' 'r' '?']
# Feature  stalk-surface-above-ring  has  4  unique values ---->  ['s' 'f' 'k' 'y']
# Feature  stalk-surface-below-ring  has  4  unique values ---->  ['s' 'f' 'y' 'k']
# Feature  stalk-color-above-ring  has  9  unique values ---->  ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# Feature  stalk-color-below-ring  has  9  unique values ---->  ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# Feature  veil-type  has  1  unique values ---->  ['p']
# Feature  veil-color  has  4  unique values ---->  ['w' 'n' 'o' 'y']
# Feature  ring-number  has  3  unique values ---->  ['o' 't' 'n']
# Feature  ring-type  has  5  unique values ---->  ['p' 'e' 'l' 'f' 'n']
# Feature  spore-print-color  has  9  unique values ---->  ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# Feature  population  has  6  unique values ---->  ['s' 'n' 'a' 'v' 'y' 'c']
# Feature  habitat  has  7  unique values ---->  ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %% [markdown]
# # Data Pre-processing Phase

# %% [markdown]
# # EDA

# %%
## checking for null values
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
# remove duplicate entries, if any
df.drop_duplicates(inplace = True)
print(df.shape)
# Out:
# (8124, 23)

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0               c         n          k           e          e
# 1               c         b          k           e          c
# 2               c         b          n           e          c
# 3               c         n          n           e          e
# 4               w         b          k           t          e
# ...           ...       ...        ...         ...        ...
# 8119            c         b          y           e          ?
# 8120            c         b          y           e          ?
# 8121            c         b          n           e          ?
# 8122            c         n          b           t          ?
# 8123            c         b          y           e          ?
#
#      stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                           s                        s                      w
# 1                           s                        s                      w
# 2                           s                        s                      w
# 3                           s                        s                      w
# 4                           s                        s                      w
# ...                       ...                      ...                    ...
# 8119                        s                        s                      o
# 8120                        s                        s                      o
# 8121                        s                        s                      o
# 8122                        s                        k                      w
# 8123                        s                        s                      o
#
#      stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                         w         p          w           o         p
# 1                         w         p          w           o         p
# 2                         w         p          w           o         p
# 3                         w         p          w           o         p
# 4                         w         p          w           o         e
# ...                     ...       ...        ...         ...       ...
# 8119                      o         p          o           o         p
# 8120                      o         p          n           o         p
# 8121                      o         p          o           o         p
# 8122                      w         p          w           o         e
# 8123                      o         p          o           o         p
#
#      spore-print-color population habitat
# 0                    k          s       u
# 1                    n          n       g
# 2                    n          n       m
# 3                    k          s       u
# 4                    n          a       g
# ...                ...        ...     ...
# 8119                 b          c       l
# 8120                 b          v       l
# 8121                 b          c       l
# 8122                 w          v       l
# 8123                 o          c       l
#
# [8124 rows x 23 columns]

# %%
for colum in df.columns:
    
        print("Feature ", colum)
    
        print("value count ", df[colum].value_counts())
# Out:
# Feature  class
# value count  e    4208
# p    3916
# Name: class, dtype: int64
# Feature  cap-shape
# value count  x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
# Feature  cap-surface
# value count  y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
# Feature  cap-color
# value count  n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# r      16
# u      16
# Name: cap-color, dtype: int64
# Feature  bruises
# value count  f    4748
# t    3376
# Name: bruises, dtype: int64
# Feature  odor
# value count  n    3528
# f    2160
# s     576
# y     576
# l     400
# a     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
# Feature  gill-attachment
# value count  f    7914
# a     210
# Name: gill-attachment, dtype: int64
# Feature  gill-spacing
# value count  c    6812
# w    1312
# Name: gill-spacing, dtype: int64
# Feature  gill-size
# value count  b    5612
# n    2512
# Name: gill-size, dtype: int64
# Feature  gill-color
# value count  b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64
# Feature  stalk-shape
# value count  t    4608
# e    3516
# Name: stalk-shape, dtype: int64
# Feature  stalk-root
# value count  b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64
# Feature  stalk-surface-above-ring
# value count  s    5176
# k    2372
# f     552
# y      24
# Name: stalk-surface-above-ring, dtype: int64
# Feature  stalk-surface-below-ring
# value count  s    4936
# k    2304
# f     600
# y     284
# Name: stalk-surface-below-ring, dtype: int64
# Feature  stalk-color-above-ring
# value count  w    4464
# p    1872
# g     576
# n     448
# b     432
# o     192
# e      96
# c      36
# y       8
# Name: stalk-color-above-ring, dtype: int64
# Feature  stalk-color-below-ring
# value count  w    4384
# p    1872
# g     576
# n     512
# b     432
# o     192
# e      96
# c      36
# y      24
# Name: stalk-color-below-ring, dtype: int64
# Feature  veil-type
# value count  p    8124
# Name: veil-type, dtype: int64
# Feature  veil-color
# value count  w    7924
# o      96
# n      96
# y       8
# Name: veil-color, dtype: int64
# Feature  ring-number
# value count  o    7488
# t     600
# n      36
# Name: ring-number, dtype: int64
# Feature  ring-type
# value count  p    3968
# e    2776
# l    1296
# f      48
# n      36
# Name: ring-type, dtype: int64
# Feature  spore-print-color
# value count  w    2388
# n    1968
# k    1872
# h    1632
# r      72
# o      48
# b      48
# u      48
# y      48
# Name: spore-print-color, dtype: int64
# Feature  population
# value count  v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# Name: population, dtype: int64
# Feature  habitat
# value count  d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: habitat, dtype: int64

# %%
for colm in df.columns:
       if len(df[colm].unique()) <= 30:
            
          print("Feature ", colm)
          df[colm].value_counts().plot(kind="bar")
          plt.show()
# Out:
# Feature  class
# Feature  cap-shape
# Feature  cap-surface
# Feature  cap-color
# Feature  bruises
# Feature  odor
# Feature  gill-attachment
# Feature  gill-spacing
# Feature  gill-size
# Feature  gill-color
# Feature  stalk-shape
# Feature  stalk-root
# Feature  stalk-surface-above-ring
# Feature  stalk-surface-below-ring
# Feature  stalk-color-above-ring
# Feature  stalk-color-below-ring
# Feature  veil-type
# Feature  veil-color
# Feature  ring-number
# Feature  ring-type
# Feature  spore-print-color
# Feature  population
# Feature  habitat

# %%
sns.set(rc = {'figure.figsize':(7,5)})

# %%
sns.histplot(x = 'cap-shape', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='cap-shape', ylabel='Count'>

# %%
sns.histplot(x = 'cap-surface', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='cap-surface', ylabel='Count'>

# %%
sns.histplot(x = 'cap-color', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='cap-color', ylabel='Count'>

# %%
sns.histplot(x = 'bruises', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='bruises', ylabel='Count'>

# %%
sns.histplot(x = 'gill-attachment', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='gill-attachment', ylabel='Count'>

# %%
sns.histplot(x = 'gill-spacing', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='gill-spacing', ylabel='Count'>

# %%
sns.histplot(x = 'odor', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='odor', ylabel='Count'>

# %%
sns.histplot(x = 'gill-size', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='gill-size', ylabel='Count'>

# %%
sns.histplot(x = 'gill-color', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='gill-color', ylabel='Count'>

# %%
sns.histplot(x = 'stalk-shape', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='stalk-shape', ylabel='Count'>

# %%
sns.histplot(x = 'stalk-root', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='stalk-root', ylabel='Count'>

# %%
sns.histplot(x = 'stalk-surface-above-ring', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='stalk-surface-above-ring', ylabel='Count'>

# %%
sns.histplot(x = 'stalk-color-above-ring', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='stalk-color-above-ring', ylabel='Count'>

# %%
sns.histplot(x = 'stalk-color-below-ring', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='stalk-color-below-ring', ylabel='Count'>

# %%
sns.histplot(x = 'veil-type', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='veil-type', ylabel='Count'>

# %%
sns.histplot(x = 'veil-color', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='veil-color', ylabel='Count'>

# %%
sns.histplot(x = 'ring-number', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='ring-number', ylabel='Count'>

# %%
sns.histplot(x = 'ring-type', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='ring-type', ylabel='Count'>

# %%
sns.histplot(x = 'spore-print-color', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='spore-print-color', ylabel='Count'>

# %%
sns.histplot(x = 'population', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='population', ylabel='Count'>

# %%
sns.histplot(x = 'habitat', data = df, hue = 'class',multiple = 'dodge')
# Out:
# <AxesSubplot:xlabel='habitat', ylabel='Count'>

# %% [markdown]
# #Checking outliers : None of the variables are numeric so not required

# %% [markdown]
# #Note:we dont need to do data manupulation as our data is already well organised and in csv file.we dont need to do data blending as it means of merging several csv files but we have only 1 csv file.Feature generation means generating more features.We have 37 features already.We can't generate more features for this dataset

# %%
# Convert Catergorical values to numeric representation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# Encode Categorical Columns
le = LabelEncoder()
#df[categ] = df[categ].apply(le.fit_transform)
df = df.apply(le.fit_transform)

# %%
#df.drop(columns = 'id', axis=1, inplace=True)

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  stalk-shape  \
# 0                   1             0          1           4            0
# 1                   1             0          0           4            0
# 2                   1             0          0           5            0
# 3                   1             0          1           5            0
# 4                   1             1          0           4            1
# ...               ...           ...        ...         ...          ...
# 8119                0             0          0          11            0
# 8120                0             0          0          11            0
# 8121                0             0          0           5            0
# 8122                1             0          1           0            1
# 8123                0             0          0          11            0
#
#       stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# 0              3                         2                         2
# 1              2                         2                         2
# 2              2                         2                         2
# 3              3                         2                         2
# 4              3                         2                         2
# ...          ...                       ...                       ...
# 8119           0                         2                         2
# 8120           0                         2                         2
# 8121           0                         2                         2
# 8122           0                         2                         1
# 8123           0                         2                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          7                       7          0           2
# 1                          7                       7          0           2
# 2                          7                       7          0           2
# 3                          7                       7          0           2
# 4                          7                       7          0           2
# ...                      ...                     ...        ...         ...
# 8119                       5                       5          0           1
# 8120                       5                       5          0           0
# 8121                       5                       5          0           1
# 8122                       7                       7          0           2
# 8123                       5                       5          0           1
#
#       ring-number  ring-type  spore-print-color  population  habitat
# 0               1          4                  2           3        5
# 1               1          4                  3           2        1
# 2               1          4                  3           2        3
# 3               1          4                  2           3        5
# 4               1          0                  3           0        1
# ...           ...        ...                ...         ...      ...
# 8119            1          4                  0           1        2
# 8120            1          4                  0           4        2
# 8121            1          4                  0           1        2
# 8122            1          0                  7           4        2
# 8123            1          4                  4           1        2
#
# [8124 rows x 23 columns]

# %% [markdown]
# # Partitioning

# %%
X = df.drop('class',axis=1)

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 0                0          1           4            0           3
# 1                0          0           4            0           2
# 2                0          0           5            0           2
# 3                0          1           5            0           3
# 4                1          0           4            1           3
# ...            ...        ...         ...          ...         ...
# 8119             0          0          11            0           0
# 8120             0          0          11            0           0
# 8121             0          0           5            0           0
# 8122             0          1           0            1           0
# 8123             0          0          11            0           0
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 0                            2                         2
# 1                            2                         2
# 2                            2                         2
# 3                            2                         2
# 4                            2                         2
# ...                        ...                       ...
# 8119                         2                         2
# 8120                         2                         2
# 8121                         2                         2
# 8122                         2                         1
# 8123                         2                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                          7                       7          0           2
# 1                          7                       7          0           2
# 2                          7                       7          0           2
# 3                          7                       7          0           2
# 4                          7                       7          0           2
# ...                      ...                     ...        ...         ...
# 8119                       5                       5          0           1
# 8120                       5                       5          0           0
# 8121                       5                       5          0           1
# 8122                       7                       7          0           2
# 8123                       5                       5          0           1
#
#       ring-number  ring-type  spore-print-color  population  habitat
# 0               1          4                  2           3        5
# 1               1          4                  3           2        1
# 2               1          4                  3           2        3
# 3               1          4                  2           3        5
# 4               1          0                  3           0        1
# ...           ...        ...                ...         ...      ...
# 8119            1          4                  0           1        2
# 8120            1          4                  0           4        2
# 8121            1          4                  0           1        2
# 8122            1          0                  7           4        2
# 8123            1          4                  4           1        2
#
# [8124 rows x 22 columns]

# %%
Y= df['class']

# %%
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
Y.value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %%
#We can see there's an imbalaned class problem.There are less proportion of enrolled

# %%
#HoldOut Validation Approach - Train-test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state = 0)

# %%
y_test.value_counts()
# Out:
# 0    1272
# 1    1166
# Name: class, dtype: int64

# %%
#Stratified Train Test Split

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X, Y, test_size = 0.30, random_state = 0, stratify = Y)

# %%
y1_train.value_counts()
# Out:
# 0    2945
# 1    2741
# Name: class, dtype: int64

# %%
y1_test.value_counts()
# Out:
# 0    1263
# 1    1175
# Name: class, dtype: int64

# %% [markdown]
# # Normalization

# %%
# Feature Scaling

# %%
#We always scale the features in the range between 0 to 1 after partitioning

# %%
X.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      3.348104     1.827671     4.504677     0.415559     4.144756
# std       1.604329     1.229873     2.545821     0.492848     2.103729
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       3.000000     2.000000     4.000000     0.000000     5.000000
# 75%       5.000000     3.000000     8.000000     1.000000     5.000000
# max       5.000000     3.000000     9.000000     1.000000     8.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      8124.000000   8124.000000  8124.000000  8124.000000  8124.000000
# mean          0.974151      0.161497     0.309207     4.810684     0.567208
# std           0.158695      0.368011     0.462195     3.540359     0.495493
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     5.000000     1.000000
# 75%           1.000000      0.000000     1.000000     7.000000     1.000000
# max           1.000000      1.000000     1.000000    11.000000     1.000000
#
#         stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# count  8124.000000               8124.000000               8124.000000
# mean      1.109798                  1.575086                  1.603644
# std       1.061106                  0.621459                  0.675974
# min       0.000000                  0.000000                  0.000000
# 25%       0.000000                  1.000000                  1.000000
# 50%       1.000000                  2.000000                  2.000000
# 75%       1.000000                  2.000000                  2.000000
# max       4.000000                  3.000000                  3.000000
#
#        stalk-color-above-ring  stalk-color-below-ring  veil-type   veil-color  \
# count             8124.000000             8124.000000     8124.0  8124.000000
# mean                 5.816347                5.794682        0.0     1.965534
# std                  1.901747                1.907291        0.0     0.242669
# min                  0.000000                0.000000        0.0     0.000000
# 25%                  6.000000                6.000000        0.0     2.000000
# 50%                  7.000000                7.000000        0.0     2.000000
# 75%                  7.000000                7.000000        0.0     2.000000
# max                  8.000000                8.000000        0.0     3.000000
#
#        ring-number    ring-type  spore-print-color   population      habitat
# count  8124.000000  8124.000000        8124.000000  8124.000000  8124.000000
# mean      1.069424     2.291974           3.596750     3.644018     1.508616
# std       0.271064     1.801672           2.382663     1.252082     1.719975
# min       0.000000     0.000000           0.000000     0.000000     0.000000
# 25%       1.000000     0.000000           2.000000     3.000000     0.000000
# 50%       1.000000     2.000000           3.000000     4.000000     1.000000
# 75%       1.000000     4.000000           7.000000     4.000000     2.000000
# max       2.000000     4.000000           8.000000     5.000000     6.000000

# %%
X_train.drop(columns = 'veil-type', axis=1, inplace=True)
X_test.drop(columns = 'veil-type', axis=1, inplace=True)

# %%
scale_vars = []

for cols in X.columns:
    if X[cols].max() > 1:
        scale_vars.append(cols)
scale_vars
# Out:
# ['cap-shape',
#  'cap-surface',
#  'cap-color',
#  'odor',
#  'gill-color',
#  'stalk-root',
#  'stalk-surface-above-ring',
#  'stalk-surface-below-ring',
#  'stalk-color-above-ring',
#  'stalk-color-below-ring',
#  'veil-color',
#  'ring-number',
#  'ring-type',
#  'spore-print-color',
#  'population',
#  'habitat']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#We will scale based on X_train and then transform both X_train and X_test

# %%
scaler.fit(X_train[scale_vars])
X_train[scale_vars] = scaler.transform(X_train[scale_vars])
X_test[scale_vars] = scaler.transform(X_test[scale_vars])

# %%
X_test.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 380         1.0     1.000000   0.444444        1  0.750                1
# 3641        0.4     1.000000   0.333333        1  0.625                1
# 273         1.0     1.000000   1.000000        1  0.000                1
# 1029        1.0     0.666667   0.888889        0  0.625                1
# 684         1.0     0.000000   0.444444        1  0.625                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 380              0          1    0.636364            0        0.75
# 3641             0          0    0.636364            1        0.25
# 273              0          0    0.363636            0        0.50
# 1029             1          0    0.363636            1        0.75
# 684              0          0    0.636364            1        0.25
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 380                   0.666667                  0.666667
# 3641                  0.666667                  0.666667
# 273                   0.666667                  0.666667
# 1029                  0.666667                  0.666667
# 684                   0.666667                  0.666667
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  \
# 380                    0.875                   0.875    0.666667          0.5
# 3641                   0.375                   0.375    0.666667          0.5
# 273                    0.875                   0.875    0.666667          0.5
# 1029                   0.875                   0.875    0.666667          0.5
# 684                    0.750                   0.875    0.666667          0.5
#
#       ring-type  spore-print-color  population   habitat
# 380         1.0              0.250         0.6  0.833333
# 3641        1.0              0.250         1.0  0.000000
# 273         1.0              0.375         0.4  0.500000
# 1029        0.0              0.250         0.0  0.166667
# 684         1.0              0.375         0.8  0.000000

# %%
X_train.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises        odor  \
# count  5686.000000  5686.000000  5686.000000  5686.000000  5686.00000
# mean      0.670489     0.610036     0.496424     0.413648     0.52117
# std       0.320792     0.410168     0.279921     0.492530     0.26174
# min       0.000000     0.000000     0.000000     0.000000     0.00000
# 25%       0.400000     0.000000     0.333333     0.000000     0.25000
# 50%       0.600000     0.666667     0.444444     0.000000     0.62500
# 75%       1.000000     1.000000     0.888889     1.000000     0.62500
# max       1.000000     1.000000     1.000000     1.000000     1.00000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      5686.000000   5686.000000  5686.000000  5686.000000  5686.000000
# mean          0.975554      0.163911     0.313401     0.438669     0.566303
# std           0.154443      0.370228     0.463917     0.322710     0.495628
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     0.181818     0.000000
# 50%           1.000000      0.000000     0.000000     0.454545     1.000000
# 75%           1.000000      0.000000     1.000000     0.636364     1.000000
# max           1.000000      1.000000     1.000000     1.000000     1.000000
#
#         stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# count  5686.000000               5686.000000               5686.000000
# mean      0.279019                  0.523977                  0.534588
# std       0.266813                  0.208304                  0.225869
# min       0.000000                  0.000000                  0.000000
# 25%       0.000000                  0.333333                  0.333333
# 50%       0.250000                  0.666667                  0.666667
# 75%       0.250000                  0.666667                  0.666667
# max       1.000000                  1.000000                  1.000000
#
#        stalk-color-above-ring  stalk-color-below-ring   veil-color  \
# count             5686.000000             5686.000000  5686.000000
# mean                 0.727686                0.726016     0.656290
# std                  0.238487                0.237794     0.076763
# min                  0.000000                0.000000     0.000000
# 25%                  0.750000                0.750000     0.666667
# 50%                  0.875000                0.875000     0.666667
# 75%                  0.875000                0.875000     0.666667
# max                  1.000000                1.000000     1.000000
#
#        ring-number    ring-type  spore-print-color   population      habitat
# count  5686.000000  5686.000000        5686.000000  5686.000000  5686.000000
# mean      0.535438     0.568062           0.452119     0.726556     0.252785
# std       0.137581     0.451478           0.297932     0.253055     0.288175
# min       0.000000     0.000000           0.000000     0.000000     0.000000
# 25%       0.500000     0.000000           0.250000     0.600000     0.000000
# 50%       0.500000     0.500000           0.375000     0.800000     0.166667
# 75%       0.500000     1.000000           0.875000     0.800000     0.333333
# max       1.000000     1.000000           1.000000     1.000000     1.000000

# %%
X_test.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  2438.000000  2438.000000  2438.000000  2438.000000  2438.000000
# mean      0.667596     0.607328     0.510072     0.420016     0.510921
# std       0.321095     0.409544     0.289461     0.493662     0.265719
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.400000     0.000000     0.333333     0.000000     0.250000
# 50%       0.600000     0.666667     0.444444     0.000000     0.625000
# 75%       1.000000     1.000000     0.888889     1.000000     0.625000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      2438.000000   2438.000000  2438.000000  2438.000000  2438.000000
# mean          0.970878      0.155865     0.299426     0.434223     0.569319
# std           0.168184      0.362802     0.458100     0.319882     0.495273
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     0.181818     0.000000
# 50%           1.000000      0.000000     0.000000     0.454545     1.000000
# 75%           1.000000      0.000000     1.000000     0.636364     1.000000
# max           1.000000      1.000000     1.000000     1.000000     1.000000
#
#         stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  \
# count  2438.000000               2438.000000               2438.000000
# mean      0.273790                  0.527482                  0.534454
# std       0.261675                  0.204465                  0.224096
# min       0.000000                  0.000000                  0.000000
# 25%       0.000000                  0.333333                  0.333333
# 50%       0.250000                  0.666667                  0.666667
# 75%       0.250000                  0.666667                  0.666667
# max       1.000000                  1.000000                  1.000000
#
#        stalk-color-above-ring  stalk-color-below-ring   veil-color  \
# count             2438.000000             2438.000000  2438.000000
# mean                 0.725543                0.720416     0.652584
# std                  0.235958                0.239849     0.089744
# min                  0.000000                0.000000     0.000000
# 25%                  0.750000                0.750000     0.666667
# 50%                  0.875000                0.875000     0.666667
# 75%                  0.875000                0.875000     0.666667
# max                  1.000000                1.000000     1.000000
#
#        ring-number    ring-type  spore-print-color   population      habitat
# count  2438.000000  2438.000000        2438.000000  2438.000000  2438.000000
# mean      0.533019     0.584495           0.443704     0.734044     0.248291
# std       0.130640     0.447818           0.297579     0.244122     0.283138
# min       0.000000     0.000000           0.000000     0.000000     0.000000
# 25%       0.500000     0.000000           0.250000     0.600000     0.000000
# 50%       0.500000     0.750000           0.375000     0.800000     0.166667
# 75%       0.500000     1.000000           0.875000     0.800000     0.333333
# max       1.000000     1.000000           1.000000     1.000000     1.000000

# %% [markdown]
# # Feature Selection

# %%
X_train.head()
# Out:
#       cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 5314        1.0     0.666667   0.888889        1  0.250                1
# 2075        1.0     0.666667   1.000000        1  0.375                1
# 5165        0.4     0.666667   0.888889        1  0.250                1
# 1155        0.0     1.000000   0.888889        1  0.000                1
# 4448        1.0     1.000000   1.000000        0  0.250                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 5314             0          0    0.272727            1        0.25
# 2075             0          0    0.363636            0        0.50
# 5165             0          0    0.636364            1        0.25
# 1155             0          0    0.363636            0        0.50
# 4448             0          0    0.272727            0        0.25
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 5314                  0.000000                  0.666667
# 2075                  0.666667                  0.666667
# 5165                  0.000000                  0.666667
# 1155                  0.666667                  0.666667
# 4448                  0.333333                  0.333333
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  \
# 5314                   0.875                   0.875    0.666667          0.5
# 2075                   0.875                   0.875    0.666667          0.5
# 5165                   0.875                   0.875    0.666667          0.5
# 1155                   0.875                   0.875    0.666667          0.5
# 4448                   0.000                   0.000    0.666667          0.5
#
#       ring-type  spore-print-color  population   habitat
# 5314        1.0              0.125         0.8  0.166667
# 2075        1.0              0.250         0.4  0.500000
# 5165        1.0              0.125         0.6  0.166667
# 1155        1.0              0.375         0.6  0.500000
# 4448        0.5              0.125         1.0  0.166667

# %%
#Algorithm 3 - Feature Selection using Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

mutual_info = mutual_info_classif(X_train, y_train, random_state = 20)
mutual_info
# Out:
# array([0.02977314, 0.02561933, 0.02329346, 0.12772706, 0.628255  ,
#        0.01362992, 0.06300471, 0.16117918, 0.28040717, 0.01428452,
#        0.09104747, 0.20093467, 0.19168216, 0.17228178, 0.16861758,
#        0.02189867, 0.01787127, 0.21608736, 0.32462425, 0.1282337 ,
#        0.10546211])

# %%
print(len(mutual_info))
print(X_train.shape)
# Out:
# 21
# (5686, 21)

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# odor                        0.628255
# spore-print-color           0.324624
# gill-color                  0.280407
# ring-type                   0.216087
# stalk-surface-above-ring    0.200935
# stalk-surface-below-ring    0.191682
# stalk-color-above-ring      0.172282
# stalk-color-below-ring      0.168618
# gill-size                   0.161179
# population                  0.128234
# bruises                     0.127727
# habitat                     0.105462
# stalk-root                  0.091047
# gill-spacing                0.063005
# cap-shape                   0.029773
# cap-surface                 0.025619
# cap-color                   0.023293
# veil-color                  0.021899
# ring-number                 0.017871
# stalk-shape                 0.014285
# gill-attachment             0.013630
# dtype: float64

# %%
plt.figure(figsize = (10, 10))
mutual_info.sort_values(ascending = False).plot.bar();

# %%
#Algorithm 4 - Feature Selection using RFECV (Recursive Feature Elimination with Cross Validation)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings('ignore')

rfc = RandomForestClassifier(random_state=101)
rfecv = RFECV(estimator=rfc, step=1, cv=StratifiedKFold(5), scoring='accuracy')
rfecv.fit(X_train, y_train)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(random_state=101), scoring='accuracy')

# %%
print('Optimal number of features: {}'.format(rfecv.n_features_))
# Out:
# Optimal number of features: 6

# %%
plt.figure(figsize=(10, 10))
plt.title('Recursive Feature Elimination with Cross-Validation', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('Number of features selected', fontsize=14, labelpad=20)
plt.ylabel('% Correct Classification', fontsize=14, labelpad=20)
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_, color='#303F9F', linewidth=3)
plt.show()

# %%
print(np.where(rfecv.support_ == False)[0])
# Out:
# [ 0  1  2  3  5  6  9 11 12 13 14 15 16 19 20]

# %%
selected_features = X_train.drop(X_train.columns[np.where(rfecv.support_ == False)[0]], axis=1)

# %%
rfecv.estimator_.feature_importances_
# Out:
# array([0.33067286, 0.17043817, 0.17638159, 0.10475138, 0.08868434,
#        0.12907166])

# %%
dset = pd.DataFrame()
dset['attr'] = selected_features.columns
dset['importance'] = rfecv.estimator_.feature_importances_
dset = dset.sort_values(by='importance', ascending=False)

plt.figure(figsize=(10, 10))
plt.barh(y=dset['attr'], width=dset['importance'], color='#1976D2')
plt.title('RFECV - Feature importances', fontsize=20, fontweight='bold', pad=20)
plt.xlabel('Importance', fontsize=14, labelpad=20)
plt.show()

# %%
dset
# Out:
#                 attr  importance
# 0               odor    0.330673
# 2         gill-color    0.176382
# 1          gill-size    0.170438
# 5  spore-print-color    0.129072
# 3         stalk-root    0.104751
# 4          ring-type    0.088684

# %%
#Algorithm 1 - Dropping Constant Features using Variance Threshold Technique

# %%
from sklearn.feature_selection import VarianceThreshold
# By default, the threshold = 0 i.e. it will remove the zero-variance threshold
var_thresh = VarianceThreshold() # by default the threshold = 0
var_thresh.fit(X_train)
# Out:
# VarianceThreshold()

# %%
print("Features Selected: ", X_train.columns[var_thresh.get_support()])
# Out:
# Features Selected:  Index(['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-color', 'ring-number', 'ring-type',
#        'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
len(X_train.columns[var_thresh.get_support()])
# Out:
# 21

# %%
#There's no feature with zero variance

# %%
#Algorithm 2 - Feature Selection with Pearson's correlation

# %%
#Idea Highly correlated features with the target variable are important features, High correlation between features, (say over 90% or over 80%) indicate the existence of duplicate features.In case of duplicate features, we do not need to take all the features but one one of them would suffice

# %%
# Let's find the feature correlations

corr = X_train.corr()
corr

# Note that the correlation values lie between -1 and +1
# A correlation value close to -1 indicates a strong negative linear correlation
# A correlation value close to +1 indicates a strong positive linear correlation
# A correlation value close to 0 indicates no linear correlation
# Out:
#                           cap-shape  cap-surface  cap-color   bruises  \
# cap-shape                  1.000000    -0.057355  -0.055263 -0.041626
# cap-surface               -0.057355     1.000000  -0.008290  0.071568
# cap-color                 -0.055263    -0.008290   1.000000  0.006903
# bruises                   -0.041626     0.071568   0.006903  1.000000
# odor                      -0.027256     0.044143  -0.380317 -0.050544
# gill-attachment            0.071711    -0.035742   0.040700  0.132958
# gill-spacing               0.006671    -0.279803   0.138991 -0.305329
# gill-size                  0.052466     0.214386  -0.163697 -0.366533
# gill-color                -0.009362    -0.164088   0.088581  0.528166
# stalk-shape                0.062648    -0.018445  -0.444655  0.090112
# stalk-root                 0.029120    -0.128702   0.328827  0.237922
# stalk-surface-above-ring  -0.033019     0.091384  -0.059814  0.463384
# stalk-surface-below-ring  -0.039804     0.111228  -0.035345  0.457986
# stalk-color-above-ring    -0.041689     0.065153   0.015511  0.081587
# stalk-color-below-ring    -0.048741     0.068806   0.011098  0.089604
# veil-color                 0.071139    -0.014942   0.034201  0.113545
# ring-number               -0.115595    -0.023136  -0.016882  0.069179
# ring-type                 -0.030338    -0.106309   0.165664  0.690517
# spore-print-color         -0.074418     0.233546  -0.295730 -0.277067
# population                 0.064911     0.015283  -0.135706  0.088827
# habitat                   -0.041892     0.168257   0.035316 -0.063266
#
#                               odor  gill-attachment  gill-spacing  gill-size  \
# cap-shape                -0.027256         0.071711      0.006671   0.052466
# cap-surface               0.044143        -0.035742     -0.279803   0.214386
# cap-color                -0.380317         0.040700      0.138991  -0.163697
# bruises                  -0.050544         0.132958     -0.305329  -0.366533
# odor                      1.000000        -0.054642      0.066291   0.310405
# gill-attachment          -0.054642         1.000000      0.070090   0.106949
# gill-spacing              0.066291         0.070090      1.000000  -0.113772
# gill-size                 0.310405         0.106949     -0.113772   1.000000
# gill-color               -0.127029        -0.126822      0.097272  -0.511826
# stalk-shape               0.457743         0.180888      0.082638   0.203379
# stalk-root               -0.196133         0.133540      0.356061  -0.338520
# stalk-surface-above-ring  0.123302        -0.081107     -0.223557   0.060565
# stalk-surface-below-ring  0.061687        -0.117787     -0.217858   0.013482
# stalk-color-above-ring    0.183559         0.103983      0.275017   0.298719
# stalk-color-below-ring    0.173756         0.103174      0.250459   0.277629
# veil-color               -0.053632         0.883669      0.072235   0.101213
# ring-number               0.110745         0.102865      0.231278  -0.174039
# ring-type                -0.278460        -0.142001     -0.202510  -0.449971
# spore-print-color         0.467878        -0.022098      0.044452   0.618288
# population               -0.048890         0.167390     -0.533499   0.147552
# habitat                  -0.022135        -0.024489     -0.154586   0.153993
#
#                           gill-color  stalk-shape  stalk-root  \
# cap-shape                  -0.009362     0.062648    0.029120
# cap-surface                -0.164088    -0.018445   -0.128702
# cap-color                   0.088581    -0.444655    0.328827
# bruises                     0.528166     0.090112    0.237922
# odor                       -0.127029     0.457743   -0.196133
# gill-attachment            -0.126822     0.180888    0.133540
# gill-spacing                0.097272     0.082638    0.356061
# gill-size                  -0.511826     0.203379   -0.338520
# gill-color                  1.000000    -0.185927    0.311231
# stalk-shape                -0.185927     1.000000   -0.160870
# stalk-root                  0.311231    -0.160870    1.000000
# stalk-surface-above-ring    0.226223     0.011008   -0.033093
# stalk-surface-below-ring    0.263375    -0.036726    0.087690
# stalk-color-above-ring     -0.063535     0.223372    0.156517
# stalk-color-below-ring     -0.076491     0.231120    0.158171
# veil-color                 -0.090570     0.154477    0.149971
# ring-number                 0.101816    -0.294360   -0.250241
# ring-type                   0.629405    -0.292554    0.209756
# spore-print-color          -0.408471     0.255431   -0.536205
# population                 -0.036447     0.083712   -0.312711
# habitat                    -0.194017    -0.282193   -0.002958
#
#                           stalk-surface-above-ring  stalk-surface-below-ring  \
# cap-shape                                -0.033019                 -0.039804
# cap-surface                               0.091384                  0.111228
# cap-color                                -0.059814                 -0.035345
# bruises                                   0.463384                  0.457986
# odor                                      0.123302                  0.061687
# gill-attachment                          -0.081107                 -0.117787
# gill-spacing                             -0.223557                 -0.217858
# gill-size                                 0.060565                  0.013482
# gill-color                                0.226223                  0.263375
# stalk-shape                               0.011008                 -0.036726
# stalk-root                               -0.033093                  0.087690
# stalk-surface-above-ring                  1.000000                  0.436824
# stalk-surface-below-ring                  0.436824                  1.000000
# stalk-color-above-ring                    0.131972                  0.104743
# stalk-color-below-ring                    0.139824                  0.106534
# veil-color                               -0.085278                 -0.072295
# ring-number                               0.113050                  0.036494
# ring-type                                 0.390392                  0.390036
# spore-print-color                         0.100344                  0.129934
# population                                0.085470                  0.042399
# habitat                                  -0.051498                 -0.032408
#
#                           stalk-color-above-ring  stalk-color-below-ring  \
# cap-shape                              -0.041689               -0.048741
# cap-surface                             0.065153                0.068806
# cap-color                               0.015511                0.011098
# bruises                                 0.081587                0.089604
# odor                                    0.183559                0.173756
# gill-attachment                         0.103983                0.103174
# gill-spacing                            0.275017                0.250459
# gill-size                               0.298719                0.277629
# gill-color                             -0.063535               -0.076491
# stalk-shape                             0.223372                0.231120
# stalk-root                              0.156517                0.158171
# stalk-surface-above-ring                0.131972                0.139824
# stalk-surface-below-ring                0.104743                0.106534
# stalk-color-above-ring                  1.000000                0.481265
# stalk-color-below-ring                  0.481265                1.000000
# veil-color                              0.065419                0.064660
# ring-number                             0.088771                0.095880
# ring-type                              -0.051240               -0.038656
# spore-print-color                       0.272483                0.252712
# population                             -0.241898               -0.243619
# habitat                                 0.036497                0.041056
#
#                           veil-color  ring-number  ring-type  \
# cap-shape                   0.071139    -0.115595  -0.030338
# cap-surface                -0.014942    -0.023136  -0.106309
# cap-color                   0.034201    -0.016882   0.165664
# bruises                     0.113545     0.069179   0.690517
# odor                       -0.053632     0.110745  -0.278460
# gill-attachment             0.883669     0.102865  -0.142001
# gill-spacing                0.072235     0.231278  -0.202510
# gill-size                   0.101213    -0.174039  -0.449971
# gill-color                 -0.090570     0.101816   0.629405
# stalk-shape                 0.154477    -0.294360  -0.292554
# stalk-root                  0.149971    -0.250241   0.209756
# stalk-surface-above-ring   -0.085278     0.113050   0.390392
# stalk-surface-below-ring   -0.072295     0.036494   0.390036
# stalk-color-above-ring      0.065419     0.088771  -0.051240
# stalk-color-below-ring      0.064660     0.095880  -0.038656
# veil-color                  1.000000     0.034824  -0.139498
# ring-number                 0.034824     1.000000   0.053906
# ring-type                  -0.139498     0.053906   1.000000
# spore-print-color           0.004551     0.338310  -0.487742
# population                  0.120136    -0.239488   0.219048
# habitat                    -0.037790     0.249844  -0.208088
#
#                           spore-print-color  population   habitat
# cap-shape                         -0.074418    0.064911 -0.041892
# cap-surface                        0.233546    0.015283  0.168257
# cap-color                         -0.295730   -0.135706  0.035316
# bruises                           -0.277067    0.088827 -0.063266
# odor                               0.467878   -0.048890 -0.022135
# gill-attachment                   -0.022098    0.167390 -0.024489
# gill-spacing                       0.044452   -0.533499 -0.154586
# gill-size                          0.618288    0.147552  0.153993
# gill-color                        -0.408471   -0.036447 -0.194017
# stalk-shape                        0.255431    0.083712 -0.282193
# stalk-root                        -0.536205   -0.312711 -0.002958
# stalk-surface-above-ring           0.100344    0.085470 -0.051498
# stalk-surface-below-ring           0.129934    0.042399 -0.032408
# stalk-color-above-ring             0.272483   -0.241898  0.036497
# stalk-color-below-ring             0.252712   -0.243619  0.041056
# veil-color                         0.004551    0.120136 -0.037790
# ring-number                        0.338310   -0.239488  0.249844
# ring-type                         -0.487742    0.219048 -0.208088
# spore-print-color                  1.000000   -0.128427  0.182316
# population                        -0.128427    1.000000 -0.174405
# habitat                            0.182316   -0.174405  1.000000

# %%
plt.figure(figsize = (20,10))
sns.heatmap(corr, annot = True, cmap = "seismic");

# %%
# use of the mask 
import numpy as np
mask1 = np.triu(np.ones_like(corr, dtype=bool))
mask2 = np.tril(np.ones_like(corr, dtype=bool))
plt.figure(figsize = (20,10))
sns.heatmap(corr, annot = True, cmap = "seismic", mask = mask1);

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is highly correlated with another feature

def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of the redundant columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i, j])) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.85) # 85% is a good value of the threshold
print(len(corr_features))
print(corr_features)
# Out:
# 1
# {'veil-color'}

# %%
X_train.drop(columns = 'veil-color', axis=1, inplace=True)
X_test.drop(columns = 'veil-color', axis=1, inplace=True)

print(X_train)
print(X_test)
# Out:
#       cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 5314        1.0     0.666667   0.888889        1  0.250                1
# 2075        1.0     0.666667   1.000000        1  0.375                1
# 5165        0.4     0.666667   0.888889        1  0.250                1
# 1155        0.0     1.000000   0.888889        1  0.000                1
# 4448        1.0     1.000000   1.000000        0  0.250                1
# ...         ...          ...        ...      ...    ...              ...
# 4931        1.0     1.000000   0.222222        1  0.625                1
# 3264        1.0     0.000000   0.333333        0  0.250                1
# 1653        1.0     0.666667   0.333333        0  0.625                1
# 2607        0.4     0.000000   0.444444        1  0.625                1
# 2732        1.0     1.000000   0.333333        1  0.625                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 5314             0          0    0.272727            1        0.25
# 2075             0          0    0.363636            0        0.50
# 5165             0          0    0.636364            1        0.25
# 1155             0          0    0.363636            0        0.50
# 4448             0          0    0.272727            0        0.25
# ...            ...        ...         ...          ...         ...
# 4931             0          0    0.090909            0        0.00
# 3264             0          0    0.272727            0        0.25
# 1653             1          0    0.272727            1        0.75
# 2607             0          0    0.454545            1        0.25
# 2732             0          0    0.909091            1        0.25
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 5314                  0.000000                  0.666667
# 2075                  0.666667                  0.666667
# 5165                  0.000000                  0.666667
# 1155                  0.666667                  0.666667
# 4448                  0.333333                  0.333333
# ...                        ...                       ...
# 4931                  0.666667                  0.666667
# 3264                  0.333333                  0.333333
# 1653                  0.000000                  0.666667
# 2607                  0.666667                  0.666667
# 2732                  0.666667                  0.666667
#
#       stalk-color-above-ring  stalk-color-below-ring  ring-number  ring-type  \
# 5314                   0.875                   0.875          0.5        1.0
# 2075                   0.875                   0.875          0.5        1.0
# 5165                   0.875                   0.875          0.5        1.0
# 1155                   0.875                   0.875          0.5        1.0
# 4448                   0.000                   0.000          0.5        0.5
# ...                      ...                     ...          ...        ...
# 4931                   0.250                   0.250          1.0        0.0
# 3264                   0.750                   0.500          0.5        0.5
# 1653                   0.875                   0.875          0.5        0.0
# 2607                   0.375                   0.375          0.5        1.0
# 2732                   0.375                   0.750          0.5        1.0
#
#       spore-print-color  population   habitat
# 5314              0.125         0.8  0.166667
# 2075              0.250         0.4  0.500000
# 5165              0.125         0.6  0.166667
# 1155              0.375         0.6  0.500000
# 4448              0.125         1.0  0.166667
# ...                 ...         ...       ...
# 4931              0.875         0.2  1.000000
# 3264              0.125         1.0  0.666667
# 1653              0.375         0.6  0.166667
# 2607              0.375         0.8  0.000000
# 2732              0.375         1.0  0.000000
#
# [5686 rows x 20 columns]
#       cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 380         1.0     1.000000   0.444444        1  0.750                1
# 3641        0.4     1.000000   0.333333        1  0.625                1
# 273         1.0     1.000000   1.000000        1  0.000                1
# 1029        1.0     0.666667   0.888889        0  0.625                1
# 684         1.0     0.000000   0.444444        1  0.625                1
# ...         ...          ...        ...      ...    ...              ...
# 520         1.0     0.666667   0.888889        1  0.375                1
# 36          0.8     0.000000   0.333333        0  0.625                1
# 7959        0.6     1.000000   0.222222        0  0.250                1
# 6520        1.0     1.000000   0.222222        0  1.000                1
# 6005        0.4     1.000000   0.222222        0  0.875                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 380              0          1    0.636364            0        0.75
# 3641             0          0    0.636364            1        0.25
# 273              0          0    0.363636            0        0.50
# 1029             1          0    0.363636            1        0.75
# 684              0          0    0.636364            1        0.25
# ...            ...        ...         ...          ...         ...
# 520              0          0    0.909091            0        0.50
# 36               0          1    0.363636            0        0.75
# 7959             0          1    0.000000            1        0.00
# 6520             0          1    0.000000            1        0.00
# 6005             0          1    0.000000            1        0.00
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 380                   0.666667                  0.666667
# 3641                  0.666667                  0.666667
# 273                   0.666667                  0.666667
# 1029                  0.666667                  0.666667
# 684                   0.666667                  0.666667
# ...                        ...                       ...
# 520                   0.666667                  0.666667
# 36                    0.666667                  0.666667
# 7959                  0.333333                  0.666667
# 6520                  0.666667                  0.666667
# 6005                  0.666667                  0.333333
#
#       stalk-color-above-ring  stalk-color-below-ring  ring-number  ring-type  \
# 380                    0.875                   0.875          0.5        1.0
# 3641                   0.375                   0.375          0.5        1.0
# 273                    0.875                   0.875          0.5        1.0
# 1029                   0.875                   0.875          0.5        0.0
# 684                    0.750                   0.875          0.5        1.0
# ...                      ...                     ...          ...        ...
# 520                    0.875                   0.875          0.5        1.0
# 36                     0.875                   0.875          0.5        1.0
# 7959                   0.875                   0.750          0.5        0.0
# 6520                   0.875                   0.875          0.5        0.0
# 6005                   0.750                   0.750          0.5        0.0
#
#       spore-print-color  population   habitat
# 380               0.250         0.6  0.833333
# 3641              0.250         1.0  0.000000
# 273               0.375         0.4  0.500000
# 1029              0.250         0.0  0.166667
# 684               0.375         0.8  0.000000
# ...                 ...         ...       ...
# 520               0.250         0.4  0.500000
# 36                0.250         0.8  0.833333
# 7959              0.875         0.8  0.333333
# 6520              0.875         0.8  0.666667
# 6005              0.875         0.8  0.000000
#
# [2438 rows x 20 columns]

# %%
X1_train.drop(columns = 'veil-color', axis=1, inplace=True)
X1_test.drop(columns = 'veil-color', axis=1, inplace=True)

print(X1_train)
print(X1_test)
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 5178          5            3          1        0     5                1
# 1196          5            0          3        0     5                1
# 1996          2            2          4        0     5                1
# 6698          2            3          2        0     8                1
# 3309          2            3          4        1     5                1
# ...         ...          ...        ...      ...   ...              ...
# 5428          2            2          8        1     2                1
# 3214          2            0          2        1     5                1
# 6351          2            3          4        0     2                1
# 6565          2            3          2        0     2                1
# 4498          5            3          4        0     8                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 5178             1          1          10            0           1
# 1196             1          0           4            1           3
# 1996             1          0           7            1           3
# 6698             0          1           0            1           0
# 3309             0          0           9            1           1
# ...            ...        ...         ...          ...         ...
# 5428             0          0          10            1           1
# 3214             0          0           5            1           1
# 6351             0          1           0            1           0
# 6565             0          1           0            1           0
# 4498             0          1           0            1           0
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 5178                         0                         0
# 1196                         0                         2
# 1996                         0                         2
# 6698                         2                         1
# 3309                         2                         2
# ...                        ...                       ...
# 5428                         2                         2
# 3214                         2                         2
# 6351                         2                         2
# 6565                         1                         2
# 4498                         2                         1
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  ring-number  \
# 5178                       7                       4          0            1
# 1196                       7                       7          0            1
# 1996                       7                       7          0            1
# 6698                       6                       6          0            1
# 3309                       6                       6          0            1
# ...                      ...                     ...        ...          ...
# 5428                       7                       7          0            1
# 3214                       7                       3          0            1
# 6351                       6                       6          0            1
# 6565                       6                       6          0            1
# 4498                       6                       6          0            1
#
#       ring-type  spore-print-color  population  habitat
# 5178          0                  7           4        2
# 1196          0                  2           3        1
# 1996          0                  3           3        1
# 6698          0                  7           4        4
# 3309          4                  3           5        0
# ...         ...                ...         ...      ...
# 5428          4                  1           3        1
# 3214          4                  2           4        0
# 6351          0                  7           4        4
# 6565          0                  7           4        4
# 4498          0                  7           4        4
#
# [5686 rows x 21 columns]
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 2144          2            3          4        1     5                1
# 2668          5            0          2        1     5                1
# 835           5            2          4        1     6                1
# 2612          2            0          4        1     5                1
# 4749          5            0          5        0     1                1
# ...         ...          ...        ...      ...   ...              ...
# 1469          5            2          4        0     5                1
# 6624          2            2          2        0     2                1
# 5850          5            3          4        0     7                1
# 7389          3            2          2        0     2                1
# 6293          2            2          2        0     7                1
#
#       gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  \
# 2144             0          0           7            1           1
# 2668             0          0          10            1           1
# 835              0          1           4            0           3
# 2612             0          0           9            1           1
# 4749             1          1           7            0           1
# ...            ...        ...         ...          ...         ...
# 1469             1          0           5            1           3
# 6624             0          1           0            1           0
# 5850             0          1           0            1           0
# 7389             0          1           0            1           0
# 6293             0          1           0            1           0
#
#       stalk-surface-above-ring  stalk-surface-below-ring  \
# 2144                         2                         2
# 2668                         2                         2
# 835                          2                         2
# 2612                         2                         2
# 4749                         2                         2
# ...                        ...                       ...
# 1469                         2                         2
# 6624                         1                         2
# 5850                         1                         1
# 7389                         2                         1
# 6293                         1                         2
#
#       stalk-color-above-ring  stalk-color-below-ring  veil-type  ring-number  \
# 2144                       7                       3          0            1
# 2668                       3                       3          0            1
# 835                        7                       7          0            1
# 2612                       7                       3          0            1
# 4749                       7                       7          0            1
# ...                      ...                     ...        ...          ...
# 1469                       7                       7          0            1
# 6624                       6                       6          0            1
# 5850                       6                       7          0            1
# 7389                       6                       7          0            1
# 6293                       6                       7          0            1
#
#       ring-type  spore-print-color  population  habitat
# 2144          4                  3           4        0
# 2668          4                  3           5        0
# 835           4                  3           4        1
# 2612          4                  3           5        0
# 4749          4                  2           3        0
# ...         ...                ...         ...      ...
# 1469          0                  2           3        1
# 6624          0                  7           4        4
# 5850          0                  7           4        0
# 7389          0                  7           4        4
# 6293          0                  7           4        2
#
# [2438 rows x 21 columns]

# %% [markdown]
# # Model Creation and Evaluation

# %%
from sklearn import metrics

# %% [markdown]
# # With train-test split

# %% [markdown]
# # ZeroR classifier

# %%
# ZeroR classifier

from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score
zerort = DummyClassifier(strategy = "most_frequent")
zerort.fit(X_train, y_train)
y_pred_train = zerort.predict(X_train)
y_pred_test = zerort.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.5163559620119592
# Test Accuracy:  0.5217391304347826

# %%
ac_zero1 = accuracy_score(y_pred_test, y_test)

# %%
ac_zero1
# Out:
# 0.5217391304347826

# %%
#As there is class imbalance issue,we need classification report as well

# %%
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1272    0]
#  [1166    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.522     1.000     0.686      1272
#            1      0.000     0.000     0.000      1166
#
#     accuracy                          0.522      2438
#    macro avg      0.261     0.500     0.343      2438
# weighted avg      0.272     0.522     0.358      2438

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt1=accuracy_score(y_test,Y_pred)

# %%
ac_dt1
# Out:
# 1.0

# %%
# Decision Tree analysis with the depth

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    dtn = DecisionTreeClassifier(max_depth=depth)
    dtn = dtn.fit(X_train, y_train)
    y_predTrain = dtn.predict(X_train)
    y_predTest = dtn.predict(X_test)
    trainAcc[index] = accuracy_score(y_train, y_predTrain)
    testAcc[index] = accuracy_score(y_test, y_predTest)
    print("Depth = ", depth, ", Training Accuracy = ", trainAcc[index], ", Test Accuracy = ", testAcc[index], 
          ", Diff = ", np.abs((trainAcc[index]-testAcc[index])*100), " %")
    index += 1

    
#########################################
# Plot of training and test accuracies
#########################################
    
plt.plot(maxdepths,trainAcc,'ro-',maxdepths,testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy');
# Out:
# Depth =  2 , Training Accuracy =  0.9069644741470277 , Test Accuracy =  0.9200164068908941 , Diff =  1.3051932743866401  %
# Depth =  3 , Training Accuracy =  0.9574393246570524 , Test Accuracy =  0.9614438063986874 , Diff =  0.40044817416350353  %
# Depth =  4 , Training Accuracy =  0.9762574744987689 , Test Accuracy =  0.9815422477440525 , Diff =  0.5284773245283647  %
# Depth =  5 , Training Accuracy =  0.9778403095321843 , Test Accuracy =  0.9827727645611156 , Diff =  0.49324550289313596  %
# Depth =  6 , Training Accuracy =  0.994899753781217 , Test Accuracy =  0.9954881050041017 , Diff =  0.058835122288469766  %
# Depth =  7 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  8 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  9 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  10 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  15 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  20 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  25 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  30 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  35 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  40 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  45 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  50 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %

# %%
# create a model 
dt1 = DecisionTreeClassifier(max_depth = 7, random_state=1)
dt1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=7, random_state=1)

# %%
Y_predt1=dt1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt2=accuracy_score(y_test,Y_predt1)

# %%
ac_dt2
# Out:
# 1.0

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred_knn=knn.predict(X_test)

# %%
ac_knn1=accuracy_score(y_test,Y_pred_knn)

# %%
ac_knn1
# Out:
# 1.0

# %%
# KNN with Euclidean Distance Metric

from sklearn.neighbors import KNeighborsClassifier
numNeighbors = [1, 5, 10, 15, 20, 25, 30,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    knn4 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    knn4.fit(X_train, y_train)
    y_predTrain = knn4.predict(X_train)
    y_predTest = knn4.predict(X_test)
    trainAcc.append(accuracy_score(y_train, y_predTrain))
    testAcc.append(accuracy_score(y_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  5 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  10 , Training Accuracy =  0.9996482588814632  Test Accuracy =  0.9983593109105825 , Difference =  0.12889479708807494 %
# K =  15 , Training Accuracy =  0.9977136827295111  Test Accuracy =  0.9971287940935193 , Difference =  0.05848886359918204 %
# K =  20 , Training Accuracy =  0.9968343299331692  Test Accuracy =  0.9967186218211649 , Difference =  0.011570811200434239 %
# K =  25 , Training Accuracy =  0.9968343299331692  Test Accuracy =  0.9963084495488105 , Difference =  0.05258803843587456 %
# K =  30 , Training Accuracy =  0.9964825888146325  Test Accuracy =  0.9950779327317474 , Difference =  0.14046560828850918 %
# K =  60 , Training Accuracy =  0.9882166725290187  Test Accuracy =  0.9909762100082035 , Difference =  0.27595374791847815 %
# K =  100 , Training Accuracy =  0.9759057333802321  Test Accuracy =  0.9770303527481542 , Difference =  0.1124619367922075 %
# K =  120 , Training Accuracy =  0.9744987689060851  Test Accuracy =  0.9749794913863823 , Difference =  0.04807224802971799 %
# K =  130 , Training Accuracy =  0.9736194161097432  Test Accuracy =  0.9721082854799016 , Difference =  0.15111306298416505 %
# K =  140 , Training Accuracy =  0.9604291241646148  Test Accuracy =  0.9602132895816243 , Difference =  0.021583458299045954 %
# K =  150 , Training Accuracy =  0.9599015124868097  Test Accuracy =  0.9585726004922067 , Difference =  0.13289119946029437 %
# K =  160 , Training Accuracy =  0.9590221596904678  Test Accuracy =  0.9573420836751435 , Difference =  0.16800760153242722 %
# K =  200 , Training Accuracy =  0.9556806190643686  Test Accuracy =  0.9544708777686628 , Difference =  0.12097412957058351 %

# %%
# KNN with Manhatten Distance Metric
numNeighbors = [1, 5, 10, 15, 20, 25, 30,40,50,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    knn7 = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=1)
    knn7.fit(X_train, y_train)
    y_predTrain = knn7.predict(X_train)
    y_predTest = knn7.predict(X_test)
    trainAcc.append(accuracy_score(y_train, y_predTrain))
    testAcc.append(accuracy_score(y_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  5 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  10 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  15 , Training Accuracy =  0.9994723883221949  Test Accuracy =  0.9995898277276456 , Difference =  0.011743940545072551 %
# K =  20 , Training Accuracy =  0.9994723883221949  Test Accuracy =  0.9995898277276456 , Difference =  0.011743940545072551 %
# K =  25 , Training Accuracy =  0.9991206472036581  Test Accuracy =  0.9995898277276456 , Difference =  0.0469180523987478 %
# K =  30 , Training Accuracy =  0.9987689060851214  Test Accuracy =  0.9995898277276456 , Difference =  0.08209216425242305 %
# K =  40 , Training Accuracy =  0.9994723883221949  Test Accuracy =  0.9995898277276456 , Difference =  0.011743940545072551 %
# K =  50 , Training Accuracy =  0.998593035525853  Test Accuracy =  0.9991796554552912 , Difference =  0.05866199294382035 %
# K =  60 , Training Accuracy =  0.9913823425958495  Test Accuracy =  0.9942575881870386 , Difference =  0.2875245591189124 %
# K =  100 , Training Accuracy =  0.9825888146324305  Test Accuracy =  0.9876948318293683 , Difference =  0.5106017196937818 %
# K =  120 , Training Accuracy =  0.9778403095321843  Test Accuracy =  0.9811320754716981 , Difference =  0.32917659395138577 %
# K =  130 , Training Accuracy =  0.9764333450580372  Test Accuracy =  0.9799015586546349 , Difference =  0.3468213596597658 %
# K =  140 , Training Accuracy =  0.9635947942314457  Test Accuracy =  0.9655455291222313 , Difference =  0.1950734890785677 %
# K =  150 , Training Accuracy =  0.9630671825536405  Test Accuracy =  0.9647251845775225 , Difference =  0.16580020238819992 %
# K =  160 , Training Accuracy =  0.9628913119943722  Test Accuracy =  0.9634946677604594 , Difference =  0.06033557660872768 %
# K =  200 , Training Accuracy =  0.9613084769609568  Test Accuracy =  0.9622641509433962 , Difference =  0.09556739824394533 %

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr8 = LogisticRegression(penalty = 'none')

lr8.fit(X_train, y_train)
y_pred_train = lr8.predict(X_train)
y_pred_test = lr8.predict(X_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
print()
ac_lr1 = accuracy_score(y_pred_test, y_test)

lr9 = LogisticRegression(penalty = 'l2')

lr9.fit(X_train, y_train)
y_pred_train = lr9.predict(X_train)
y_pred_test = lr9.predict(X_test)
print("Logistic Regression with L2 regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9424903271192402
# Test Accuracy:  0.9397046759639048
#
# Logistic Regression with L2 regularization
# Train Accuracy:  0.9474147027787548
# Test Accuracy:  0.9470877768662839

# %%
ac_lr1
# Out:
# 0.9397046759639048

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred_rf=rf.predict(X_test)

# %%
ac_rf1=accuracy_score(y_test,Y_pred_rf)

# %%
ac_rf1
# Out:
# 1.0

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.7856137882518467
# Test Accuracy:  0.7961443806398687

# %%
ac_perceptron1 = accuracy_score(y_pred_test, y_test)

# %%
ac_perceptron1
# Out:
# 0.7961443806398687

# %%
# Multinomial Naive Bayes

from sklearn.naive_bayes import MultinomialNB
mlf = MultinomialNB()
mlf.fit(X_train, y_train)
y_pred_train = mlf.predict(X_train)
y_pred_test = mlf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.8566654941962716
# Test Accuracy:  0.8560295324036095

# %%
ac_naive1 = accuracy_score(y_pred_test, y_test)

# %%
ac_naive1
# Out:
# 0.8560295324036095

# %%
from sklearn.svm import SVC
slf = SVC(gamma = 'auto', random_state = 0)
slf.fit(X_train, y_train)
y_pred_train = slf.predict(X_train)
y_pred_test = slf.predict(X_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
# Out:
# Train Accuracy:  0.9620119591980303
# Test Accuracy:  0.9622641509433962

# %%
# for the SVC classifier
from sklearn import metrics
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1228   44]
#  [  48 1118]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.962     0.965     0.964      1272
#            1      0.962     0.959     0.960      1166
#
#     accuracy                          0.962      2438
#    macro avg      0.962     0.962     0.962      2438
# weighted avg      0.962     0.962     0.962      2438

# %%
ac_svc1 = accuracy_score(y_pred_test, y_test)

# %%
ac_svc1
# Out:
# 0.9622641509433962

# %%
plt.figure(figsize = (10,5))
plt.bar(['Decision Tree ','Logistic','KNN','Random Forest','SVM','Naive Bayes','Perceptron','ZeroR'],[ac_dt2,ac_lr1,ac_knn1,ac_rf1,ac_svc1,ac_naive1,ac_perceptron1,ac_zero1])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Hyper Parameter Optimization

# %% [markdown]
# # Logistic regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
clf6 = LogisticRegression(penalty = 'none')

clf6.fit(X_train, y_train)
y_pred_train = clf6.predict(X_train)
y_pred_test = clf6.predict(X_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y_test))
print()
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9424903271192402
# Test Accuracy:  0.9397046759639048

# %%
clf6.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.947237 using {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.941846 (0.008707) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.941846 (0.008707) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.941787 (0.008748) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.942256 (0.008061) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.942256 (0.008061) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.942549 (0.008001) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.947237 (0.007407) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.947237 (0.007407) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.946299 (0.007043) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.941433 (0.007312) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.941433 (0.007312) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.940612 (0.007823) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.910832 (0.010425) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.910832 (0.010425) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.915581 (0.009910) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
grid_y_predicted = grid_result.predict(X_test)

# %%
grid_y_predicted
# Out:
# array([1, 0, 0, ..., 1, 1, 1])

# %%
logis_grid_score=accuracy_score(y_test, grid_y_predicted)

# %%
logis_grid_score
# Out:
# 0.9470877768662839

# %% [markdown]
# Accuracy did not improve much after hyper parameter tuning

# %% [markdown]
# # With Stratified Train Test split

# %%
from sklearn import metrics

# %% [markdown]
# # With train-test split

# %% [markdown]
# # ZeroR classifier

# %%
# ZeroR classifier

from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score
clf = DummyClassifier(strategy = "most_frequent")
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.5179387970453746
# Test Accuracy:  0.5180475799835931

# %%
ac_zero2 = accuracy_score(y_pred_test, y1_test)

# %%
ac_zero2
# Out:
# 0.5180475799835931

# %%
#As there is class imbalance issue,we need classification report as well

# %%
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y1_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y1_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1263    0]
#  [1175    0]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      0.518     1.000     0.683      1263
#            1      0.000     0.000     0.000      1175
#
#     accuracy                          0.518      2438
#    macro avg      0.259     0.500     0.341      2438
# weighted avg      0.268     0.518     0.354      2438

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

# %%
dt.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dt.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt4=accuracy_score(y1_test,Y_pred)

# %%
ac_dt4
# Out:
# 1.0

# %%
# Decision Tree analysis with the depth

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
maxdepths = [2,3,4,5,6,7,8,9,10,15,20,25,30,35,40,45,50]
trainAcc = np.zeros(len(maxdepths))
testAcc = np.zeros(len(maxdepths))

index = 0
for depth in maxdepths:
    clf = DecisionTreeClassifier(max_depth=depth)
    clf = clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc[index] = accuracy_score(y1_train, y_predTrain)
    testAcc[index] = accuracy_score(y1_test, y_predTest)
    print("Depth = ", depth, ", Training Accuracy = ", trainAcc[index], ", Test Accuracy = ", testAcc[index], 
          ", Diff = ", np.abs((trainAcc[index]-testAcc[index])*100), " %")
    index += 1

    
#########################################
# Plot of training and test accuracies
#########################################
    
plt.plot(maxdepths,trainAcc,'ro-',maxdepths,testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Max depth')
plt.ylabel('Accuracy');
# Out:
# Depth =  2 , Training Accuracy =  0.9085473091804432 , Test Accuracy =  0.9163248564397046 , Diff =  0.7777547259261386  %
# Depth =  3 , Training Accuracy =  0.9595497713682729 , Test Accuracy =  0.9565217391304348 , Diff =  0.30280322378380964  %
# Depth =  4 , Training Accuracy =  0.9780161800914526 , Test Accuracy =  0.9774405250205086 , Diff =  0.05756550709440367  %
# Depth =  5 , Training Accuracy =  0.9797748856841365 , Test Accuracy =  0.9782608695652174 , Diff =  0.15140161189191037  %
# Depth =  6 , Training Accuracy =  0.9991206472036581 , Test Accuracy =  0.9987694831829368 , Diff =  0.035116402072132846  %
# Depth =  7 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  8 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  9 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  10 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  15 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  20 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  25 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  30 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  35 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  40 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  45 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %
# Depth =  50 , Training Accuracy =  1.0 , Test Accuracy =  1.0 , Diff =  0.0  %

# %%
# create a model 
dt5 = DecisionTreeClassifier(max_depth = 2, random_state=1)
dt5.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=1)

# %%
Y_predt1=dt5.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac_dt2=accuracy_score(y1_test,Y_predt1)

# %%
ac_dt2
# Out:
# 0.9163248564397046

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred_knn=knn.predict(X1_test)

# %%
ac_knn1=accuracy_score(y1_test,Y_pred_knn)

# %%
ac_knn1
# Out:
# 0.9979491386382281

# %%
# KNN with Euclidean Distance Metric

from sklearn.neighbors import KNeighborsClassifier
numNeighbors = [1, 5, 10, 15, 20, 25, 30,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=2)
    clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc.append(accuracy_score(y1_train, y_predTrain))
    testAcc.append(accuracy_score(y1_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  0.9983593109105825 , Difference =  0.1640689089417502 %
# K =  5 , Training Accuracy =  0.9996482588814632  Test Accuracy =  0.9979491386382281 , Difference =  0.16991202432351526 %
# K =  10 , Training Accuracy =  0.9978895532887795  Test Accuracy =  0.994667760459393 , Difference =  0.3221792829386505 %
# K =  15 , Training Accuracy =  0.9963067182553641  Test Accuracy =  0.9942575881870386 , Difference =  0.2049130068325522 %
# K =  20 , Training Accuracy =  0.9912064720365811  Test Accuracy =  0.9909762100082035 , Difference =  0.023026202837761467 %
# K =  25 , Training Accuracy =  0.9887442842068238  Test Accuracy =  0.9897456931911403 , Difference =  0.10014089843164431 %
# K =  30 , Training Accuracy =  0.984699261343651  Test Accuracy =  0.9848236259228876 , Difference =  0.012436457923659106 %
# K =  60 , Training Accuracy =  0.963770664790714  Test Accuracy =  0.9659557013945858 , Difference =  0.2185036603871704 %
# K =  100 , Training Accuracy =  0.9514597256419275  Test Accuracy =  0.9561115668580804 , Difference =  0.4651841216152919 %
# K =  120 , Training Accuracy =  0.9461836088638762  Test Accuracy =  0.9511894995898277 , Difference =  0.5005890725951478 %
# K =  130 , Training Accuracy =  0.940555750967288  Test Accuracy =  0.9462674323215751 , Difference =  0.5711681354287013 %
# K =  140 , Training Accuracy =  0.9386211748153359  Test Accuracy =  0.94298605414274 , Difference =  0.43648793274040365 %
# K =  150 , Training Accuracy =  0.9365107281041154  Test Accuracy =  0.9401148482362592 , Difference =  0.360412013214384 %
# K =  160 , Training Accuracy =  0.9324657052409426  Test Accuracy =  0.9376538146021329 , Difference =  0.5188109361190296 %
# K =  200 , Training Accuracy =  0.9257826239887443  Test Accuracy =  0.9310910582444627 , Difference =  0.5308434255718364 %

# %%
# KNN with Manhatten Distance Metric
numNeighbors = [1, 5, 10, 15, 20, 25, 30,40,50,60,100,120,130,140,150,160,200]
trainAcc = []
testAcc = []

for k in numNeighbors:
    clf = KNeighborsClassifier(n_neighbors=k, metric='minkowski', p=1)
    clf.fit(X1_train, y1_train)
    y_predTrain = clf.predict(X1_train)
    y_predTest = clf.predict(X1_test)
    trainAcc.append(accuracy_score(y1_train, y_predTrain))
    testAcc.append(accuracy_score(y1_test, y_predTest))

plt.plot(numNeighbors, trainAcc, 'ro-', numNeighbors, testAcc,'bv--')
plt.legend(['Training Accuracy','Test Accuracy'])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy');

index = 0
for i in numNeighbors:
    print("K = ", numNeighbors[index], ", Training Accuracy = ", trainAcc[index], " Test Accuracy = ", testAcc[index], 
          ", Difference = ", np.abs(trainAcc[index]-testAcc[index])*100, "%")
    index+=1
# Out:
# K =  1 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  5 , Training Accuracy =  1.0  Test Accuracy =  1.0 , Difference =  0.0 %
# K =  10 , Training Accuracy =  0.9992965177629265  Test Accuracy =  0.9983593109105825 , Difference =  0.09372068523439969 %
# K =  15 , Training Accuracy =  0.9994723883221949  Test Accuracy =  0.9983593109105825 , Difference =  0.11130774116123732 %
# K =  20 , Training Accuracy =  0.9992965177629265  Test Accuracy =  0.9983593109105825 , Difference =  0.09372068523439969 %
# K =  25 , Training Accuracy =  0.9992965177629265  Test Accuracy =  0.9983593109105825 , Difference =  0.09372068523439969 %
# K =  30 , Training Accuracy =  0.9992965177629265  Test Accuracy =  0.9983593109105825 , Difference =  0.09372068523439969 %
# K =  40 , Training Accuracy =  0.9987689060851214  Test Accuracy =  0.9983593109105825 , Difference =  0.04095951745388682 %
# K =  50 , Training Accuracy =  0.9915582131551178  Test Accuracy =  0.9913863822805579 , Difference =  0.017183087455996393 %
# K =  60 , Training Accuracy =  0.9882166725290187  Test Accuracy =  0.9885151763740772 , Difference =  0.029850384505847316 %
# K =  100 , Training Accuracy =  0.9810059795990151  Test Accuracy =  0.9807219031993437 , Difference =  0.028407639967142906 %
# K =  120 , Training Accuracy =  0.9794231445655998  Test Accuracy =  0.9799015586546349 , Difference =  0.04784140890351507 %
# K =  130 , Training Accuracy =  0.979071403447063  Test Accuracy =  0.9799015586546349 , Difference =  0.08301552075719032 %
# K =  140 , Training Accuracy =  0.9780161800914526  Test Accuracy =  0.9799015586546349 , Difference =  0.18853785631822717 %
# K =  150 , Training Accuracy =  0.9746746394653535  Test Accuracy =  0.9774405250205086 , Difference =  0.2765885555155112 %
# K =  160 , Training Accuracy =  0.9730918044319381  Test Accuracy =  0.9770303527481542 , Difference =  0.3938548316216095 %
# K =  200 , Training Accuracy =  0.9686950404502286  Test Accuracy =  0.972518457752256 , Difference =  0.38234173020273987 %

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
lr2 = LogisticRegression(penalty = 'none')

lr2.fit(X1_train, y1_train)
y_pred_train = lr2.predict(X1_train)
y_pred_test = lr2.predict(X1_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
print()
ac_lr1 = accuracy_score(y_pred_test, y1_test)

clf = LogisticRegression(penalty = 'l2')

clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Logistic Regression with L2 regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9458318677453394
# Test Accuracy:  0.9454470877768663
#
# Logistic Regression with L2 regularization
# Train Accuracy:  0.9468870911009497
# Test Accuracy:  0.9433962264150944

# %%
ac_lr1
# Out:
# 0.9454470877768663

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X1_train,y1_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred_rf=rf.predict(X1_test)

# %%
ac_rf1=accuracy_score(y1_test,Y_pred_rf)

# %%
ac_rf1
# Out:
# 1.0

# %%
from sklearn.linear_model import Perceptron
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.9370383397819205
# Test Accuracy:  0.9360131255127153

# %%
ac_perceptron1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_perceptron1
# Out:
# 0.9360131255127153

# %%
# Multinomial Naive Bayes

from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  0.795990151248681
# Test Accuracy:  0.8022969647251845

# %%
ac_naive1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_naive1
# Out:
# 0.8022969647251845

# %%
from sklearn.svm import SVC
clf = SVC(gamma = 'auto', random_state = 0)
clf.fit(X1_train, y1_train)
y_pred_train = clf.predict(X1_train)
y_pred_test = clf.predict(X1_test)
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
# Out:
# Train Accuracy:  1.0
# Test Accuracy:  1.0

# %%
# for the SVC classifier
from sklearn import metrics
print("Confusion Matrix for the Test Case")
print(metrics.confusion_matrix(y1_test, y_pred_test))
print()
print("Classification Report")
print(metrics.classification_report(y1_test, y_pred_test, digits = 3))
# Out:
# Confusion Matrix for the Test Case
# [[1263    0]
#  [   0 1175]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0      1.000     1.000     1.000      1263
#            1      1.000     1.000     1.000      1175
#
#     accuracy                          1.000      2438
#    macro avg      1.000     1.000     1.000      2438
# weighted avg      1.000     1.000     1.000      2438

# %%
ac_svc1 = accuracy_score(y_pred_test, y1_test)

# %%
ac_svc1
# Out:
# 1.0

# %%
plt.figure(figsize = (10,5))
plt.bar(['Decision Tree ','Logistic','KNN','Random Forest','SVM','Naive Bayes','Perceptron','ZeroR'],[ac_dt4,ac_lr1,ac_knn1,ac_rf1,ac_svc1,ac_naive1,ac_perceptron1,ac_zero2])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# # Logistic regression

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
clf6 = LogisticRegression(penalty = 'none')

clf6.fit(X1_train, y1_train)
y_pred_train = clf6.predict(X1_train)
y_pred_test = clf6.predict(X1_test)
print("Logistic Regression with no regularization")
print("Train Accuracy: ", accuracy_score(y_pred_train, y1_train))
print("Test Accuracy: ", accuracy_score(y_pred_test, y1_test))
print()
# Out:
# Logistic Regression with no regularization
# Train Accuracy:  0.9458318677453394
# Test Accuracy:  0.9454470877768663

# %%
clf6.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
# define models and parameters
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X1_train, y1_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.946593 using {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.943603 (0.008109) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.946593 (0.007307) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.943544 (0.008050) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.943603 (0.008346) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.946359 (0.008266) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.943544 (0.008387) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.945421 (0.007246) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.944659 (0.007234) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.943253 (0.007364) with: {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.937098 (0.007942) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.936981 (0.008074) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.935046 (0.007708) with: {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.905324 (0.007411) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.905324 (0.007411) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.908958 (0.008250) with: {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
grid_y_predicted = grid_result.predict(X1_test)

# %%
grid_y_predicted
# Out:
# array([0, 0, 1, ..., 1, 1, 1])

# %%
logis_grid_score=accuracy_score(y1_test, grid_y_predicted)

# %%
logis_grid_score
# Out:
# 0.9450369155045119

# %% [markdown]
# Accuracy did not improve much after hyper parameter tuning
